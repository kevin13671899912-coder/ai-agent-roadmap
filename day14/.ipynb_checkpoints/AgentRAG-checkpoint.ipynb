# %%
import os
from langchain.tools import tool
from langchain.chat_models import init_chat_model


if "ANTHROPIC_AUTH_TOKEN" in os.environ and "ANTHROPIC_API_KEY" not in os.environ:
    os.environ["ANTHROPIC_API_KEY"] = os.environ["ANTHROPIC_AUTH_TOKEN"]

model = init_chat_model(
    "claude-sonnet-5",
    model_provider="anthropic",
    temperature=0
)


COMPANY_KNOWLEDGE = {
    "annual_leave": {
        "content": "2026年员工手册规定：正式员工每年享有10天带薪年假，试用期员工不享受带薪年假。",
        "source": "员工手册2026",
        "page": 23,
    },

    "expense": {
        "content": "单笔报销超过5000元，需要部门负责人审批。",
        "source": "财务制度2026",
        "page": 12,
    },
}



@tool
def search_company_knowledge(query: str) -> dict:
    """搜索公司制度、员工手册和内部规范。"""

    if "年假" in query or "试用期" in query:
        return COMPANY_KNOWLEDGE["annual_leave"]

    if "报销" in query:
        return COMPANY_KNOWLEDGE["expense"]

    return {
        "error": "knowledge_not_found"
    }

EMPLOYEE_DB = {
    "E1001": {
        "name": "张三",
        "status": "probation",
        "annual_leave_balance": 0,
        "department": "研发部",
    },

    "E1002": {
        "name": "李四",
        "status": "regular",
        "annual_leave_balance": 7,
        "department": "财务部",
    },
}


@tool
def query_employee(employee_id: str) -> dict:
    """查询员工当前实时信息，包括员工状态、部门和年假余额。"""

    employee = EMPLOYEE_DB.get(employee_id)

    if employee is None:
        return {
            "error": "employee_not_found"
        }

    return employee

from typing_extensions import TypedDict, Annotated
import operator

from langchain.messages import AnyMessage
from langgraph.graph.message import add_messages
class AgentState(TypedDict):
    messages: Annotated[
        list[AnyMessage],
        add_messages,
    ]


from langchain.messages import ToolMessage
tools = [
    query_employee,
    search_company_knowledge,
]

tools_by_name = {
    tool.name: tool
    for tool in tools
}

model_with_tools = model.bind_tools(tools)

from langchain.messages import SystemMessage

def agent_node(state: AgentState):

    response = model_with_tools.invoke(
        [
            SystemMessage(
                content="""
你是公司内部AI助手。

规则：

1. 查询员工当前状态、余额等实时信息时，
   必须使用 query_employee。

2. 查询公司制度、员工手册、规范时，
   必须使用 search_company_knowledge。

3. 如果一个问题同时涉及实时员工信息和公司制度，
   可以连续调用多个工具。

4. 不允许编造公司内部信息。

5. 如果知识库没有找到资料，
   明确告诉用户无法确认。
"""
            )
        ]
        + state["messages"]
    )

    return {
        "messages": [response]
    }









def tool_node(state: AgentState):
    last_message = state["messages"][-1]

    results = []

    for tool_call in last_message.tool_calls:
        tool = tools_by_name[
            tool_call["name"]
        ]

        observation = tool.invoke(
            tool_call["args"]
        )

        results.append(
            ToolMessage(
                content=str(observation),
                tool_call_id=tool_call["id"],
            )
        )

    return {
        "messages": results
    }

    



# Step 5: Define logic to determine whether to end
from typing import Literal
from langgraph.graph import END


def route_after_agent(
    state: AgentState,
) -> Literal["tools", "__end__"]:

    last_message = state["messages"][-1]

    if last_message.tool_calls:
        return "tools"

    return END
    



# Step 6: Build agent
from langgraph.graph import (
    START,
    StateGraph,
)


builder = StateGraph(AgentState)

builder.add_node(
    "agent",
    agent_node,
)

builder.add_node(
    "tools",
    tool_node,
)

builder.add_edge(
    START,
    "agent",
)

builder.add_conditional_edges(
    "agent",
    route_after_agent,
    {
        "tools": "tools",
        "__end__": END,
    },
)

builder.add_edge(
    "tools",
    "agent",
)

graph = builder.compile()


from langchain.messages import HumanMessage


from IPython.display import Image, display
# Show the agent
display(
    Image(
        graph.get_graph().draw_mermaid_png()
    )
)

# Invoke
resultDepartment = graph.invoke({
    "messages": [
        HumanMessage(
            content=(
                "试用期员工有年假吗？"
            )
        )
    ]
})

for message in resultDepartment["messages"]:
    message.pretty_print()
    

resultWeather = graph.invoke({
    "messages": [
        HumanMessage(
            content=(
                "E1002 现在还有多少年假？"
            )
        )
    ]
})


for message in resultWeather["messages"]:
    message.pretty_print()


result = graph.invoke({
    "messages": [
        HumanMessage(
            content=(
                "E1001 为什么没有年假？"
            )
        )
    ]
})

for message in result["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 试用期员工有年假吗？
# ================================== Ai Message ==================================
#
# [{'data': 'gAAAAABqe_AA7J-L-knXhMgk9CtooJRu5YjzJIvJiUNRYo9DRqoK6xX2_1EgyZQAqFnsDDozl7OtVA7kyaGQwHGWPpT_iidgWtwWPU7x4sdR1gDecLL8dXpXJTMOI715DSPk5CSnZKQKOuvsVXr9xO7uw9xyHQHm36fGwrJDC-2VQ-SJLFYQkxPwC_wNaFLOUSBWhW-7b4JvdZLt5SA759PHCPAKyQGKbj2oViD0ha-dTHiIQR3_uzTki0EsCmgEKDaii4IZvPcgQrVIsQnqmAbRHh0JJnhKMU3u7N57hFMTmXfqqGcualQvDyclfPc82lCg3jqE9n2B1EVAkGhFRVdtds7Azivs6mKGJ0LYzP2-3uagIxp-V0yBcmrz2BZL_M5CUMj8hMpArRWpI4mdjZB_Mqe42eF-UXLVKw2ZijT3gZ29UHBcC12EZGKj64Mg0v_tItx7DdfV2aBSq6juvqiwM6h_AENJILr5vAjgQcCW-LpSYQsREbRHCFa7-oLiC17Vjmwi7eXxX3L-1rQK7l_4g-2qFca-swkc7TyIfyZW5e396a-OBhT1F7RpCD7AQ_vHLigK62tarBZ-HfL_hd5WCBGP_RP7EOzp6vInbepqrsr4ngZrPZw9-AP6nRDSUv4MDTyIlybWXzvdwQSS8urAnEC-ZE--naE8vK2fOOXIDz85R11ufEYjSAbHxNyIkpi26LQYoce0Zvmeo83U3C3tVnKyfgCESH93RKkPtfavQ9SgCOkQAIB6L_RYBOASOU_ncSP-rURE2r8_lDOJ-2H8vjghejiZSjt-YMQS0mW-AJCt7KD_qYv5jj0ulIZHjoF4bWM40bgDt6_iDJ9TyBXUSFwW-BWpKaGVVMiK5HyPluosFUgxEd-c8JeCymfV2ISIYSiFtRTnRe_gSpTtk-xzarK6_GS2LwTaZIZAJmuaNSwFDu0VDtDBSqHiC0GADqxgjk7gmFkQ3ZMRR8C2M5zL4peKapoWNYzsTxCIdhqEIpu7RMsy_m8=', 'type': 'redacted_thinking', 'id': 'rs_033f8b00fb754fe6016a7befffba7881988d0f4a2c266cf81a'}, {'id': 'call_sYDk5HWSlosdwgEFyw2KzqgG', 'input': {'query': '试用期员工是否享有年假？请查找公司年假制度、员工手册中关于试用期员工年假资格、计算和休假限制的规定。'}, 'name': 'search_company_knowledge', 'type': 'tool_use'}]
# Tool Calls:
#   search_company_knowledge (call_sYDk5HWSlosdwgEFyw2KzqgG)
#  Call ID: call_sYDk5HWSlosdwgEFyw2KzqgG
#   Args:
#     query: 试用期员工是否享有年假？请查找公司年假制度、员工手册中关于试用期员工年假资格、计算和休假限制的规定。
# ================================= Tool Message =================================
#
# {'content': '2026年员工手册规定：正式员工每年享有10天带薪年假，试用期员工不享受带薪年假。', 'source': '员工手册2026', 'page': 23}
# ================================== Ai Message ==================================
#
# 根据《员工手册2026》第23页，**试用期员工不享受带薪年假**；转为正式员工后，每年享有 **10天带薪年假**。
# ================================ Human Message =================================
#
# E1002 现在还有多少年假？
# ================================== Ai Message ==================================
#
# [{'id': 'call_vZXXNVIZeoH1Q0wBYw6Cs35v', 'input': {'employee_id': 'E1002'}, 'name': 'query_employee', 'type': 'tool_use'}]
# Tool Calls:
#   query_employee (call_vZXXNVIZeoH1Q0wBYw6Cs35v)
#  Call ID: call_vZXXNVIZeoH1Q0wBYw6Cs35v
#   Args:
#     employee_id: E1002
# ================================= Tool Message =================================
#
# {'name': '李四', 'status': 'regular', 'annual_leave_balance': 7, 'department': '财务部'}
# ================================== Ai Message ==================================
#
# E1002（李四）当前还有 **7天年假**。
# ================================ Human Message =================================
#
# E1001 为什么没有年假？
# ================================== Ai Message ==================================
#
# [{'data': 'gAAAAABqe_ANhw79ZSViekSdWx7VjcypUQWuOImZSoRMuQn9dMXF_46kVHTipIWyKZmU_ROkpQ99aHZUdEUENe4IUqtv8GMitHJRn6F-NuLRaKNfu63TRKn0OcEkeJYVEWKmiy9UFe7chawmQ9EWUGu_3PgoGRo09nyC-fUMvnIhCdkUY5obQhdfD1PqhkE-91u1ZOFFI64bQQMxkWzZmAObsYbSUqP5E9pJHDm88Y7_stty9nasIu9J9-t_yFhYYZEkNgl-0C6klESuiF8u68Wj545JQf4xfyTw6RukV9ftGozlN5vZR_igpkbhS2F1CUM5XzOXMdyUGeHfWw5F2K47cYVocbqT7BEQTw1okgnhycW46sEoHxJcX6ecIRXQiFnsi3x6FaZOAFyGxntXv_R12aMZokKtDp71V-gP8U1jfpvl8UPYXy_1rJFEnq-SlBX-oCENNrDUC5j8Vu1Dz7h4ZSF9KE6Rfca_HNRHB1Ce8zQHAjL9azewOCZ_ooVhDJtAZ1-own-p0GFOTfSnKs71kD0cNR-wcQ-xuP3_4Rb7s6DG_nZJY9Ds_YhCgnByKzaV-Sz2v1BCzR6EN244tKrTZE09Pjbb9RfnX6qhJKUah-wxhAzLc2bZ5G7j4lR_YglG6kbpUbwnBSKvdXGOE6usRqoP5AcoYsoSM-Xh3iE2LgGayDgG7yvNOh34m0OAP8MCTQg45KysSDDUrrsAq2I7c6aVVjWiPceQrf8aiu_RyWowgvzm-xL6FXRbtN5K9uleab6x2-riedYghFGDcIM1wP6FKxVNFwf0ZKKIKXQTLtun0kcv0WK0j4jTT9PUd4Q5eIrWHGWItlzc88KWVziap49J4BdLP-_fDzzqNun9eSCePCpOM0BPs0DDWArR1_o_HKqEl0pxc3UzAiOqkUOA833R3CxlGTNcOjgHYrPje2bGgq56rkITHXDecW3fJuToAQX4RHu0QTeWIP0cPLBNKFnDztLAhxJYFiLaCyuWT8ZhRI6GJmBI9rZ_UL1Jt0O5ajmjeA63', 'type': 'redacted_thinking', 'id': 'rs_0fa352ecd28b792b016a7bf00b0e348199a135139ca714c016'}, {'id': 'call_SSBcT3pvbbOpWpB6E5Ev2iVS', 'input': {'employee_id': 'E1001'}, 'name': 'query_employee', 'type': 'tool_use'}, {'id': 'call_QlFBskcmllsWCANqbBln0qx9', 'input': {'query': '员工年假资格、年假余额为零或没有年假的原因，包括入职年限、休假额度生成、已休年假、过期清零等规定'}, 'name': 'search_company_knowledge', 'type': 'tool_use'}]
# Tool Calls:
#   query_employee (call_SSBcT3pvbbOpWpB6E5Ev2iVS)
#  Call ID: call_SSBcT3pvbbOpWpB6E5Ev2iVS
#   Args:
#     employee_id: E1001
#   search_company_knowledge (call_QlFBskcmllsWCANqbBln0qx9)
#  Call ID: call_QlFBskcmllsWCANqbBln0qx9
#   Args:
#     query: 员工年假资格、年假余额为零或没有年假的原因，包括入职年限、休假额度生成、已休年假、过期清零等规定
# ================================= Tool Message =================================
#
# {'name': '张三', 'status': 'probation', 'annual_leave_balance': 0, 'department': '研发部'}
# ================================= Tool Message =================================
#
# {'content': '2026年员工手册规定：正式员工每年享有10天带薪年假，试用期员工不享受带薪年假。', 'source': '员工手册2026', 'page': 23}
# ================================== Ai Message ==================================
#
# E1001（张三）目前处于**试用期**，年假余额为 **0 天**。
#
# 根据《员工手册2026》第 23 页：**正式员工每年享有 10 天带薪年假，试用期员工不享受带薪年假。**因此当前没有年假；转为正式员工后，才会按公司制度享有带薪年假。
