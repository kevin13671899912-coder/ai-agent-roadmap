# %%
import uuid
import time
import random
from typing_extensions import TypedDict
from IPython.display import Image, display
from langgraph.graph import START, END, StateGraph

# ==========================================
# 1. 模拟系统配置与存储
# ==========================================
MAX_RETRIES = 3  # Retry Budget
IDEMPOTENCY_STORE = {}

# ==========================================
# 2. 定义状态
# ==========================================
class AgentState(TypedDict):
    employee_id: str
    amount: int
    idempotency_key: str
    retry_count: int
    status: str
    error_code: int       # 用于判断 HTTP 状态码
    error_msg: str
    result: dict

# ==========================================
# 3. 核心工具与算法
# ==========================================
def calculate_retry_delay(
    retry_count: int,
    base_delay: float = 1.0,
    max_delay: float = 8.0,
    random_fn=random.uniform,
) -> float:
    """计算带有 Jitter 的指数退避时间"""
    max_backoff = min(
        base_delay * (2 ** retry_count),
        max_delay,
    )
    # Jitter 随机化，防止系统恢复时的重试雪崩 (Thundering Herd)
    return random_fn(0, max_backoff)


# ==========================================
# 4. 图节点定义
# ==========================================
def prepare_operation_node(state: AgentState):
    """节点 1：生成幂等键，准备调用"""
    operation_id = state.get("idempotency_key") or str(uuid.uuid4())
    print(f"[1. 准备阶段] 生成请求幂等键 Idempotency Key: {operation_id}")
    return {
        "idempotency_key": operation_id,
        "retry_count": 0,
        "status": "prepared",
    }

def call_hr_api_node(state: AgentState):
    """节点 2：模拟调用 HR API"""
    print(f"\n[2. API 调用] 第 {state.get('retry_count', 0) + 1} 次请求 HR API...")
    
    # 这里模拟底层系统故障，持续返回 503 Service Unavailable
    print("  -> [HR API 响应] 💥 503 Service Unavailable")
    return {
        "status": "error",
        "error_code": 503,
        "error_msg": "HR API Service Unavailable"
    }

def handle_error_node(state: AgentState):
    """节点 3：错误判定、退避与重试控制"""
    error_code = state.get("error_code")
    current_retry = state.get("retry_count", 0)
    
    # 步骤 A: 判断是否是 Retryable (例如 503 临时不可用, 429 限流, 504 超时)
    if error_code in [503, 504, 429]:
        # 步骤 B: 检查是否超过 Retry Budget
        if current_retry < MAX_RETRIES:
            # 步骤 C: Calculate backoff + jitter
            delay = calculate_retry_delay(current_retry)
            print(f"  -> [重试策略] 命中可重试错误 ({error_code})。当前重试 {current_retry}/{MAX_RETRIES}。")
            print(f"  -> [重试策略] 触发 Backoff + Jitter，Sleep 等待 {delay:.2f} 秒...")
            
            # 步骤 D: Sleep
            time.sleep(delay) 
            
            return {
                "status": "retryable_error",
                "retry_count": current_retry + 1
            }
        else:
            # 步骤 E: 超过 retry budget -> fallback
            print(f"  -> [重试策略] ❌ 已达最大重试次数 ({MAX_RETRIES})，重试预算耗尽！")
            return {"status": "fallback"}
    else:
        # 非可重试错误（如 400 参数错误, 403 权限不足），直接 fallback
        print(f"  -> [重试策略] 非可重试错误 ({error_code})，直接放弃。")
        return {"status": "fallback"}

def fallback_node(state: AgentState):
    """节点 4：Fallback 降级处理"""
    print("\n[3. Fallback] ⚠️ 进入降级流程：将请求推入死信队列 (Dead-letter Queue) / 通知人工干预，并返回兜底响应。")
    return {
        "status": "fallback_completed",
        "result": {
            "success": False,
            "fallback_applied": True,
            "message": "System busy, your request has been queued for manual processing."
        }
    }

# ==========================================
# 5. 图路由与构建
# ==========================================
def route_after_api(state: AgentState):
    if state["status"] == "error":
        return "handle_error"
    return END

def route_after_error(state: AgentState):
    if state["status"] == "retryable_error":
        return "call_hr_api"  # 回去继续调 API
    return "fallback"         # 否则进入兜底

builder = StateGraph(AgentState)
builder.add_node("prepare", prepare_operation_node)
builder.add_node("call_hr_api", call_hr_api_node)
builder.add_node("handle_error", handle_error_node)
builder.add_node("fallback", fallback_node)

builder.add_edge(START, "prepare")
builder.add_edge("prepare", "call_hr_api")

# 调用 API 后的分支判断
builder.add_conditional_edges("call_hr_api", route_after_api, {
    "handle_error": "handle_error",
    END: END
})

# 错误处理后的分支判断
builder.add_conditional_edges("handle_error", route_after_error, {
    "call_hr_api": "call_hr_api",
    "fallback": "fallback"
})

builder.add_edge("fallback", END)

graph = builder.compile()

# 显示流程图
try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    pass


# ==========================================
# 6. 执行与观测
# ==========================================
if __name__ == "__main__":
    print("【开始发奖金请求】")
    print("="*60)
    
    final_state = graph.invoke({
        "employee_id": "E1001",
        "amount": 5000
    })
    
    print("="*60)
    print("【最终状态】", final_state["result"])
# Out:
# 【开始发奖金请求】
# ...
# [1. 准备阶段] 生成请求幂等键 Idempotency Key: 24b320ac-df43-44f3-afe7-04de9d04e481
#
# [2. API 调用] 第 1 次请求 HR API...
#   -> [HR API 响应] 💥 503 Service Unavailable
#   -> [重试策略] 命中可重试错误 (503)。当前重试 0/3。
#   -> [重试策略] 触发 Backoff + Jitter，Sleep 等待 0.24 秒...
#
# [2. API 调用] 第 2 次请求 HR API...
#   -> [HR API 响应] 💥 503 Service Unavailable
#   -> [重试策略] 命中可重试错误 (503)。当前重试 1/3。
#   -> [重试策略] 触发 Backoff + Jitter，Sleep 等待 1.65 秒...
#
# [2. API 调用] 第 3 次请求 HR API...
#   -> [HR API 响应] 💥 503 Service Unavailable
#   -> [重试策略] 命中可重试错误 (503)。当前重试 2/3。
#   -> [重试策略] 触发 Backoff + Jitter，Sleep 等待 1.26 秒...
#
# [2. API 调用] 第 4 次请求 HR API...
#   -> [HR API 响应] 💥 503 Service Unavailable
#   -> [重试策略] ❌ 已达最大重试次数 (3)，重试预算耗尽！
#
# [3. Fallback] ⚠️ 进入降级流程：将请求推入死信队列 (Dead-letter Queue) / 通知人工干预，并返回兜底响应。
# ...
# 【最终状态】 {'success': False, 'fallback_applied': True, 'message': 'System busy, your request has been queued for manual processing.'}
